# %%
# Imports and Global Variables
import os 
import cv2
from datetime import datetime
import numba 
from numba import jit
import numpy as np
import scipy as sc
import math
from numpy.random import default_rng
rng = default_rng()
import cmath
from numba import cuda
cuda.select_device(0)
global IMAGENR ; IMAGENR=100
global THREADS ; THREADS=700
global Gf , Rf, Bf, Zf, If
Gf=2.0;Rf=2.0;Bf=2.0;Zf=0.0;If=0
global COLOR_DEPTH
COLOR_DEPTH=255

# Fractal Calculation Functions
def calculate_mandelbrot_imageC(Ny, Nx, itmax, center, scl, IMG):
    x1 = center[1] - Nx / (2 * scl); x2 = center[1] + Nx / (2 * scl)
    y1 = center[0] - Ny / (2 * scl); y2 = center[0] + Ny / (2 * scl)
    warp = 32
    blx = warp; bly = math.ceil(THREADS / warp)
    grx = math.ceil(Nx / blx); gry = math.ceil(Ny / bly)
    blockdim = (blx, bly); griddim = (grx, gry)
    d_image = cuda.to_device(IMG)
    mandel_kernel[griddim, blockdim](x1, x2, y1, y2, d_image, itmax)
    IMG = d_image.copy_to_host()
    return IMG

@cuda.jit(device=True)
def mandel(x, y, max):
    c = complex(y, x)
    z = 0.0j
    for i in range(max):
        z = (z * z) + c  # Original Mandelbrot
        if (z.real * z.real + z.imag * z.imag) >= 4:
            return i
    return max

@cuda.jit
def mandel_kernel(min_x, max_x, min_y, max_y, image, iters):
    height = image.shape[0]
    width = image.shape[1]
    pixel_size_x = (max_x - min_x) / width
    pixel_size_y = (max_y - min_y) / height
    startX = cuda.blockDim.x * cuda.blockIdx.x + cuda.threadIdx.x
    startY = cuda.blockDim.y * cuda.blockIdx.y + cuda.threadIdx.y
    gridX = cuda.gridDim.x * cuda.blockDim.x
    gridY = cuda.gridDim.y * cuda.blockDim.y
    for x in range(startX, width, gridX):
        real = min_x + (x * pixel_size_x)
        for y in range(startY, height, gridY):
            imag = min_y + (y * pixel_size_y)
            image[y, x] = mandel(real, imag, iters) / iters

# Field of Interest Calculation
def calculate_foiC(M, foi):
    hy = M.shape[0]
    wx = M.shape[1]
    warp = 32
    blx = warp; bly = math.ceil(THREADS / warp)
    grx = math.ceil(wx / blx); gry = math.ceil(hy / bly)
    blockdim = (blx, bly); griddim = (grx, gry)
    m_image = cuda.to_device(M)
    f_image = cuda.to_device(foi)
    foi_kernel[griddim, blockdim](m_image, f_image)
    foi = f_image.copy_to_host()
    return foi

@cuda.jit
def foi_kernel(fimagein, fimageout):
    height = fimagein.shape[0]
    width = fimagein.shape[1]
    startX = cuda.blockDim.x * cuda.blockIdx.x + cuda.threadIdx.x
    startY = cuda.blockDim.y * cuda.blockIdx.y + cuda.threadIdx.y
    gridX = cuda.gridDim.x * cuda.blockDim.x
    gridY = cuda.gridDim.y * cuda.blockDim.y
    for x in range(startX, width, gridX):
        for y in range(startY, height, gridY):
            p = fimagein[y, x]; dev = 0
            for t in range(-2, 3, 1):
                for u in range(-2, 3, 1):
                    if y + t >= 0 and y + t < height and x + u >= 0 and x + u < width:
                        dev = dev + (p - fimagein[y + t, x + u]) * (p - fimagein[y + t, x + u])
            fimageout[y, x] = dev / 25

# Fractal Array Filtering
def filter_fracC(fr, cv, fmap):
    hy = fr.shape[0]
    wx = fr.shape[1]
    cd = fmap.shape[1]
    warp = 32
    blx = warp; bly = math.ceil(THREADS / warp); blz = 1
    grx = math.ceil(wx / blx); gry = math.ceil(hy / bly); grz = cd
    blockdim = (blx, bly, blz); griddim = (grx, gry, grz)
    f_image = cuda.to_device(fr)
    c_image = cuda.to_device(cv)
    f_map = cuda.to_device(fmap)
    filter_kernel[griddim, blockdim](f_image, c_image, f_map)
    cv = c_image.copy_to_host()
    return cv

@cuda.jit
def filter_kernel(frac, cvimg, fmap):
    hy = frac.shape[0]
    wx = frac.shape[1]
    fy = fmap.shape[0]
    fx = fmap.shape[1]
    startX = cuda.blockDim.x * cuda.blockIdx.x + cuda.threadIdx.x
    startY = cuda.blockDim.y * cuda.blockIdx.y + cuda.threadIdx.y
    startZ = cuda.blockDim.z * cuda.blockIdx.z + cuda.threadIdx.z
    gridX = cuda.gridDim.x * cuda.blockDim.x
    gridY = cuda.gridDim.y * cuda.blockDim.y
    gridZ = cuda.gridDim.z * cuda.blockDim.z
    for x in range(startX, wx, gridX):
        for y in range(startY, hy, gridY):
            p = frac[y, x]
            av = 0; wg = 0
            if p < 0.2 or p > 0.80:
                for t in range(0, fy, 1):
                    tt = int(t - (fy - 1) / 2)
                    for u in range(0, fx, 1):
                        uu = int(u - (fx - 1) / 2)
                        if (y + tt) >= 0 and (y + tt) < hy and (x + uu) >= 0 and (x + uu) < wx:
                            wg = wg + fmap[t, u]
                            av = av + frac[y + tt, x + uu] * fmap[t, u]
                cvimg[y, x] = av / wg
            else:
                cvimg[y, x] = p

# Color Mapping
def cmap_cvimageC(fr, cv, cmap):
    hy = fr.shape[0]
    wx = fr.shape[1]
    cd = cmap.shape[1]
    warp = 32
    blx = warp; bly = math.ceil(THREADS / warp); blz = 1
    grx = math.ceil(wx / blx); gry = math.ceil(hy / bly); grz = cd
    blockdim = (blx, bly, blz); griddim = (grx, gry, grz)
    f_image = cuda.to_device(fr)
    c_image = cuda.to_device(cv)
    m_image = cuda.to_device(cmap)
    cmap_kernel[griddim, blockdim](f_image, c_image, m_image)
    cv = c_image.copy_to_host()
    return cv

@cuda.jit
def cmap_kernel(frac, cvimg, cmap):
    hy = frac.shape[0]
    wx = frac.shape[1]
    rr = cmap.shape[0]
    cd = cmap.shape[1]
    startX = cuda.blockDim.x * cuda.blockIdx.x + cuda.threadIdx.x
    startY = cuda.blockDim.y * cuda.blockIdx.y + cuda.threadIdx.y
    startZ = cuda.blockDim.z * cuda.blockIdx.z + cuda.threadIdx.z
    gridX = cuda.gridDim.x * cuda.blockDim.x
    gridY = cuda.gridDim.y * cuda.blockDim.y
    gridZ = cuda.gridDim.z * cuda.blockDim.z
    for x in range(startX, wx, gridX):
        for y in range(startY, hy, gridY):
            index = int(frac[y, x] * (rr - 1))
            index = index % rr
            for z in range(startZ, cd, gridZ):
                cvimg[y, x, z] = cmap[index, z]

# Zoom Point Calculation
def calculate_zoompoint(foi, centero, resy, resx, scale, slce):
    foi_r = np.where(foi > np.max(foi) * 0.3)  # results in 2 1-dimensional arrays: col and row
    s = np.array([0])
    if slce == 0:
        s = np.random.uniform(0, foi_r[0].size - 1, 1)
    else:
        s[0] = foi_r[0].size * (slce % 1)
    xindex = foi_r[1][int(s[0])]
    yindex = foi_r[0][int(s[0])]
    centern = (centero[0] + (yindex - resy / 2) / scale, centero[1] + (xindex - resx / 2) / scale, yindex, xindex)
    return centern  # Return the center coordinates and array indices

def create_cmap(buf, seed):
    global Rf; global Bf
    global Gf; global Zf; global If
    r = 0; g = 0; b = 0; inv = 0
    x = buf.shape[0]
    if seed == 0:  # seed 0 is Gray scale
        r = 4; g = 4; b = 4; inv = 0
    else:
        if seed == 99:  # color frequency by keyboard
            r = Rf
            g = Gf
            b = Bf
            inv = If
        else:  # other seed is random
            r = np.random.uniform(0.85, 1.95, 1)
            g = np.random.uniform(0.85, 1.95, 1)
            b = np.random.uniform(0.85, 1.95, 1)
            Rf = r; Bf = b; Gf = g; If = inv
    for i in range(0, x, 1):
        if i * 1 * math.pi / x < 1 * math.pi / 6 or i * 1 * math.pi / x > 5 * math.pi / 6:
            l1 = math.cos(i * 3 * math.pi / x - math.pi / 2)
        else:
            l1 = 0.75 + math.cos(i * 3 * math.pi / x - math.pi / 2) / 4
        if l1 > 1:
            l1 = 1
        buf[x - i - 1][0] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * r * math.pi / x - Zf * math.pi / 2)) / 2))
        buf[x - i - 1][1] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * g * math.pi / x - Zf * math.pi / 2)) / 2))
        buf[x - i - 1][2] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * b * math.pi / x - Zf * math.pi / 2)) / 2))
        r = r * 1.001; g = g * 1.001; b = b * 1.001
    buf.reshape(x, 3)
    return buf

# %%
# Set initial parameters
iterate_max = 1024
center = (-0.75, 0, 0, 0)
scale = 100.0
Ny = 1080
Nx = 1920
Zf = 0.0

# Initialize arrays
BASE = np.array(np.zeros((Ny, Nx), dtype=np.float64))
FOI = BASE.copy()
IMAGE_BUF = np.zeros((Ny, Nx, 3), dtype=np.uint8)
CMAP_BUF = np.zeros((iterate_max, 3), dtype=np.uint8)
CMAP_BUF = create_cmap(CMAP_BUF, 2)
FMAP_BUF = np.matrix([
    [0.0, 0.0, 0.2, 0.0, 0.0],
    [0.0, 0.2, 0.5, 0.2, 0.0],
    [0.2, 0.5, 0.0, 0.5, 0.2],
    [0.0, 0.2, 0.5, 0.2, 0.0],
    [0.0, 0.0, 0.2, 0.0, 0.0]], dtype=np.float64)

# Calculate initial fractal
t = datetime.now()
FRAC = calculate_mandelbrot_imageC(Ny, Nx, iterate_max, center, scale, BASE)
NFRAC = calculate_mandelbrot_imageC(Ny, Nx, iterate_max, center, scale, BASE)
FRAC = filter_fracC(NFRAC, FRAC, FMAP_BUF)
t = datetime.now() - t
print(t)

# Save initial color map and fractal image
C = CMAP_BUF.reshape(1, iterate_max, 3)
C = np.repeat(C, 32, axis=0)
cv2.imwrite("CMAP.png", C)
frame = cmap_cvimageC(FRAC, IMAGE_BUF, CMAP_BUF)
cv2.imwrite("MandelOrg.png", frame)

# Perform zoom iterations
for i in range(0, 8, 1):
    FOI = calculate_foiC(FRAC, FOI)
    center = calculate_zoompoint(FOI, center, Ny, Nx, scale, 0)
    print(f"Zoom iteration {i}: center = {center}")
    scale = scale * 1.5
    FRAC = calculate_mandelbrot_imageC(Ny, Nx, iterate_max, center, scale, FRAC)
frame = cmap_cvimageC(FRAC, IMAGE_BUF, CMAP_BUF)
cv2.imwrite("Videostart" + str(i) + ".png", frame)

# Stream video
frame = cmap_cvimageC(FRAC, IMAGE_BUF, CMAP_BUF)
ncenter = center

# Define the codec and create VideoWriter object. The output is stored in 'Fractal.avi' file.
out = cv2.VideoWriter('Fractal.avi', cv2.VideoWriter_fourcc('M', 'J', 'P', 'G'), 40, (Nx, Ny))

for j in range(0, 8, 1):
    FOI = calculate_foiC(FRAC, FOI)
    ncenter = calculate_zoompoint(FOI, center, Ny, Nx, scale, 0)
    zstep = 140
    ystep = (ncenter[0] - center[0]) / zstep
    xstep = (ncenter[1] - center[1]) / zstep
    for i in range(0, zstep, 1):
        cuda.synchronize()
        scale = scale * 1.015
        Zf = (Zf + 0.005)
        CMAP_BUF = create_cmap(CMAP_BUF, 99)
        center = (center[0] + ystep, center[1] + xstep, 0, 0)
        NFRAC = calculate_mandelbrot_imageC(Ny, Nx, iterate_max, center, scale, BASE)
        FRAC = filter_fracC(NFRAC, FRAC, FMAP_BUF)
        frame = cmap_cvimageC(FRAC, IMAGE_BUF, CMAP_BUF)
        cv2.imshow('frame2', frame)
        out.write(frame)
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):
            break
out.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\reeff\AppData\Local\Temp\ipykernel_18840\321667516.py:209: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   buf[x - i - 1][0] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * r * math.pi / x - Zf * math.pi / 2)) / 2))
# C:\Users\reeff\AppData\Local\Temp\ipykernel_18840\321667516.py:210: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   buf[x - i - 1][1] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * g * math.pi / x - Zf * math.pi / 2)) / 2))
# C:\Users\reeff\AppData\Local\Temp\ipykernel_18840\321667516.py:211: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   buf[x - i - 1][2] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * b * math.pi / x - Zf * math.pi / 2)) / 2))
# 0:00:01.715430
# Zoom iteration 0: center = (0.19999999999999996, 0.56, 635, 1016)
# Zoom iteration 1: center = (0.18666666666666662, 0.5533333333333333, 538, 959)
# Zoom iteration 2: center = (-0.031111111111111145, -0.6466666666666666, 491, 690)
# Zoom iteration 3: center = (-0.528888888888889, 0.5296296296296298, 372, 1357)
# Zoom iteration 4: center = (-1.1649382716049383, 0.23728395061728408, 218, 812)
# Zoom iteration 5: center = (-1.3611522633744857, 0.03185185185185199, 391, 804)
# Zoom iteration 6: center = (-1.0161316872427983, 0.2680109739369, 933, 1229)
# Zoom iteration 7: center = (-0.9131229995427526, 0.2545496113397349, 716, 937)
# C:\Users\reeff\AppData\Local\Temp\ipykernel_18840\321667516.py:209: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   buf[x - i - 1][0] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * r * math.pi / x - Zf * math.pi / 2)) / 2))
# C:\Users\reeff\AppData\Local\Temp\ipykernel_18840\321667516.py:210: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   buf[x - i - 1][1] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * g * math.pi / x - Zf * math.pi / 2)) / 2))
# C:\Users\reeff\AppData\Local\Temp\ipykernel_18840\321667516.py:211: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   buf[x - i - 1][2] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * b * math.pi / x - Zf * math.pi / 2)) / 2))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 64
#      62 scale = scale * 1.015
#      63 Zf = (Zf + 0.005)
# ---> 64 CMAP_BUF = create_cmap(CMAP_BUF, 99)
#      65 center = (center[0] + ystep, center[1] + xstep, 0, 0)
#      66 NFRAC = calculate_mandelbrot_imageC(Ny, Nx, iterate_max, center, scale, BASE)
#
# Cell In[3], line 209, in create_cmap(buf, seed)
#     207 if l1 > 1:
#     208     l1 = 1
# --> 209 buf[x - i - 1][0] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * r * math.pi / x - Zf * math.pi / 2)) / 2))
#     210 buf[x - i - 1][1] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * g * math.pi / x - Zf * math.pi / 2)) / 2))
#     211 buf[x - i - 1][2] = abs(COLOR_DEPTH * inv - int(COLOR_DEPTH * l1 * (1 + math.sin(i * b * math.pi / x - Zf * math.pi / 2)) / 2))
#
# KeyboardInterrupt:
